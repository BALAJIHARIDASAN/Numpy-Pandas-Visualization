# %%
import pandas as pd

# %% [markdown]
# Reading the file

# %%
df = pd.read_table('drinks.csv',sep = ',')

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df.tail()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 188  Venezuela            333              100              3
# 189    Vietnam            111                2              1
# 190      Yemen              6                0              0
# 191     Zambia             32               19              4
# 192   Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 188                           7.7  South America
# 189                           2.0           Asia
# 190                           0.1           Asia
# 191                           2.5         Africa
# 192                           4.7         Africa

# %%
# filtering and slicing the data frame

# %%
# filtering

df['country'].head()
# Out:
# 0    Afghanistan
# 1        Albania
# 2        Algeria
# 3        Andorra
# 4         Angola
# Name: country, dtype: object

# %%
# multiple filtering

df[['country','continent']].head()
# Out:
#        country continent
# 0  Afghanistan      Asia
# 1      Albania    Europe
# 2      Algeria    Africa
# 3      Andorra    Europe
# 4       Angola    Africa

# %%
#rename columns in a pandas

df.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
df.rename(columns={'country':'Country'})# inplace should be used to make permanent change
# Out:
#          Country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
#replace all underscore with spaces in the column names by using the 'str.replace' method

# %%
df.columns = df.columns.str.replace('_',' ')

# %%
df.head()
# Out:
#        country  beer servings  spirit servings  wine servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total litres of pure alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
# remove columns in pandas

df.drop('continent',axis =1).head() # inplace should be used to make permanent change
# Out:
#        country  beer servings  spirit servings  wine servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total litres of pure alcohol
# 0                           0.0
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9

# %%
df.drop(['continent','country'],axis =1)
# Out:
#      beer servings  spirit servings  wine servings  \
# 0                0                0              0
# 1               89              132             54
# 2               25                0             14
# 3              245              138            312
# 4              217               57             45
# ..             ...              ...            ...
# 188            333              100              3
# 189            111                2              1
# 190              6                0              0
# 191             32               19              4
# 192             64               18              4
#
#      total litres of pure alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# 4                             5.9
# ..                            ...
# 188                           7.7
# 189                           2.0
# ...

# %%
# remove rows

df.drop([1,5],axis =0)
# Out:
#          country  beer servings  spirit servings  wine servings  \
# 0    Afghanistan              0                0              0
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# 6      Argentina            193               25            221
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total litres of pure alcohol      continent
# 0                             0.0           Asia
# 2                             0.7         Africa
# ...

# %%
# sorting in pandas

df['total litres of pure alcohol'].sort_values(ascending = False)
# Out:
# 15     14.4
# 98     12.9
# 3      12.4
# 68     11.9
# 45     11.8
#        ...
# 79      0.0
# 90      0.0
# 128     0.0
# 97      0.0
# 0       0.0
# Name: total litres of pure alcohol, Length: 193, dtype: float64

# %%
# sorting the index

df.sort_index(ascending = False)
# Out:
#          country  beer servings  spirit servings  wine servings  \
# 192     Zimbabwe             64               18              4
# 191       Zambia             32               19              4
# 190        Yemen              6                0              0
# 189      Vietnam            111                2              1
# 188    Venezuela            333              100              3
# ..           ...            ...              ...            ...
# 4         Angola            217               57             45
# 3        Andorra            245              138            312
# 2        Algeria             25                0             14
# 1        Albania             89              132             54
# 0    Afghanistan              0                0              0
#
#      total litres of pure alcohol      continent
# 192                           4.7         Africa
# 191                           2.5         Africa
# ...

# %%
# filtering using loc and iloc

# %%
df.head()
# Out:
#        country  beer servings  spirit servings  wine servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total litres of pure alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df.iloc[1:5]['country'] # filter using index position
# Out:
# 1    Albania
# 2    Algeria
# 3    Andorra
# 4     Angola
# Name: country, dtype: object

# %%
df.set_index('country',inplace = True)

# %%
df.loc['Albania'] # filter using index value
# Out:
# beer servings                       89
# spirit servings                    132
# wine servings                       54
# total litres of pure alcohol       4.9
# continent                       Europe
# Name: Albania, dtype: object

# %%
df.iloc[1:5]
# Out:
#          beer servings  spirit servings  wine servings  \
# country
# Albania             89              132             54
# Algeria             25                0             14
# Andorra            245              138            312
# Angola             217               57             45
#
#          total litres of pure alcohol continent
# country
# Albania                           4.9    Europe
# Algeria                           0.7    Africa
# Andorra                          12.4    Europe
# Angola                            5.9    Africa

# %%
# filtering

df[df['continent']=='Africa'].head()
# Out:
#               beer servings  spirit servings  wine servings  \
# country
# Algeria                  25                0             14
# Angola                  217               57             45
# Benin                    34                4             13
# Botswana                173               35             35
# Burkina Faso             25                7              7
#
#               total litres of pure alcohol continent
# country
# Algeria                                0.7    Africa
# Angola                                 5.9    Africa
# Benin                                  1.1    Africa
# Botswana                               5.4    Africa
# Burkina Faso                           4.3    Africa

# %%
df.reset_index(inplace = True)

# %%
# logical operator
#and: True only if both sides of the operator are True
# or: True if either side of the operator is True

# %% [markdown]
# Rules for specifying **multiple filter criteria** in pandas:
#
# - use **`&`** instead of **`and`**
# - use **`|`** instead of **`or`**
# - add **parentheses** around each condition to specify evaluation order

# %%
df[(df['continent']=='Africa') & (df['total litres of pure alcohol']<15)].head()
# Out:
#          country  beer servings  spirit servings  wine servings  \
# 2        Algeria             25                0             14
# 4         Angola            217               57             45
# 18         Benin             34                4             13
# 22      Botswana            173               35             35
# 26  Burkina Faso             25                7              7
#
#     total litres of pure alcohol continent
# 2                            0.7    Africa
# 4                            5.9    Africa
# 18                           1.1    Africa
# 22                           5.4    Africa
# 26                           4.3    Africa

# %%
df.dtypes
# Out:
# country                          object
# beer servings                     int64
# spirit servings                   int64
# wine servings                     int64
# total litres of pure alcohol    float64
# continent                        object
# dtype: object

# %%
# filtering categorical and numerical columns
import numpy as np


df_num = df.select_dtypes(include = np.number)
df_num.dtypes
# Out:
# beer servings                     int64
# spirit servings                   int64
# wine servings                     int64
# total litres of pure alcohol    float64
# dtype: object

# %%
df_cat = df.select_dtypes(exclude = np.number)
df_cat.dtypes
# Out:
# country      object
# continent    object
# dtype: object

# %%
# string methods in pandas

# %%
df_cat.head()
# Out:
#        country continent
# 0  Afghanistan      Asia
# 1      Albania    Europe
# 2      Algeria    Africa
# 3      Andorra    Europe
# 4       Angola    Africa

# %%
df['country'].str.upper()
# Out:
# 0      AFGHANISTAN
# 1          ALBANIA
# 2          ALGERIA
# 3          ANDORRA
# 4           ANGOLA
#           ...
# 188      VENEZUELA
# 189        VIETNAM
# 190          YEMEN
# 191         ZAMBIA
# 192       ZIMBABWE
# Name: country, Length: 193, dtype: object

# %%
df['country'].str.lower()
# Out:
# 0      afghanistan
# 1          albania
# 2          algeria
# 3          andorra
# 4           angola
#           ...
# 188      venezuela
# 189        vietnam
# 190          yemen
# 191         zambia
# 192       zimbabwe
# Name: country, Length: 193, dtype: object

# %%
df[df['country'].str.contains('Albania')]
# Out:
#    country  beer servings  spirit servings  wine servings  \
# 1  Albania             89              132             54
#
#    total litres of pure alcohol continent
# 1                           4.9    Europe

# %%
# change data types


df.head()
# Out:
#        country  beer servings  spirit servings  wine servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total litres of pure alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df.dtypes
# Out:
# country                          object
# beer servings                     int64
# spirit servings                   int64
# wine servings                     int64
# total litres of pure alcohol    float64
# continent                        object
# dtype: object

# %%
df['total litres of pure alcohol'].astype('float').head()
# Out:
# 0     0.0
# 1     4.9
# 2     0.7
# 3    12.4
# 4     5.9
# Name: total litres of pure alcohol, dtype: float64

# %%
df.dtypes
# Out:
# country                          object
# beer servings                     int64
# spirit servings                   int64
# wine servings                     int64
# total litres of pure alcohol    float64
# continent                        object
# dtype: object

# %%
# group by 

df.head()
# Out:
#        country  beer servings  spirit servings  wine servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total litres of pure alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df.groupby('continent')['total litres of pure alcohol'].sum()
# Out:
# continent
# Africa           159.4
# Asia              95.5
# Europe           387.8
# North America    137.9
# Oceania           54.1
# South America     75.7
# Name: total litres of pure alcohol, dtype: float64

# %%
df.groupby('continent')['total litres of pure alcohol'].count()
# Out:
# continent
# Africa           53
# Asia             44
# Europe           45
# North America    23
# Oceania          16
# South America    12
# Name: total litres of pure alcohol, dtype: int64

# %%
# muliple aggregation

df.groupby('continent')['total litres of pure alcohol'].agg(['count','max','min'])
# Out:
#                count   max  min
# continent
# Africa            53   9.1  0.0
# Asia              44  11.5  0.0
# Europe            45  14.4  0.0
# North America     23  11.9  2.2
# Oceania           16  10.4  0.0
# South America     12   8.3  3.8

# %%
# null values

df.isnull().sum()
# Out:
# country                         0
# beer servings                   0
# spirit servings                 0
# wine servings                   0
# total litres of pure alcohol    0
# continent                       0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# country                         193
# beer servings                   193
# spirit servings                 193
# wine servings                   193
# total litres of pure alcohol    193
# continent                       193
# dtype: int64

# %%
df.isna().sum()
# Out:
# country                         0
# beer servings                   0
# spirit servings                 0
# wine servings                   0
# total litres of pure alcohol    0
# continent                       0
# dtype: int64

# %%
df.dropna()
# Out:
#          country  beer servings  spirit servings  wine servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total litres of pure alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [country, beer servings, spirit servings, wine servings, total litres of pure alcohol, continent]
# Index: []
